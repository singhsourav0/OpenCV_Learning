# %% [markdown]
# <a href="https://colab.research.google.com/github/singhsourav0/OpenCV_Learning/blob/main/Image_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **First repo on OpenCV Learning journey ...**
#
# ---
#
# ## ⏸

# %% [markdown]
# # ![image.png](data:image/png;base64,...)https://www.instagram.com/singhsourav0/

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow
import random

# Read the image
image = cv2.imread("ss.jpeg" , 0)

# Display the image with a title
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=460x460>

# %% [markdown]
# # Resizing the Image

# %%
#Rotate and Resize
img1 = cv2.imread("ss.jpeg", -1)
img1 = cv2.resize(img1, (200, 200))
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
#Custom Resizing
img2 = cv2.resize(img1, (0, 0), fx = 1.6 ,fy = .8)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=320x160>

# %% [markdown]
# **Rotating the Image**

# %%
#Rotating
img3 = cv2.rotate(img2,cv2.ROTATE_90_CLOCKWISE)
cv2.imwrite('newss.jpeg', img3)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=160x320>

# %% [markdown]
# ## Image Fundamental & Manipulation

# %%
print(type(img1))
print(img1)
print("----------------")
print(img1.shape)
print(img1[70][40])
# Out:
# <class 'numpy.ndarray'>
# [[[124  96  79]
#   [124  96  79]
#   [124  96  79]
#   ...
#   [117  90  69]
#   [118  91  71]
#   [116  88  71]]
#
#  [[123  95  78]
#   [123  95  78]
#   [123  95  78]
#   ...
#   [118  91  70]
#   [119  92  72]
#   [117  88  72]]
#
#  [[124  96  79]
#   [124  96  79]
#   [124  96  79]
#   ...
#   [119  92  71]
#   [119  92  72]
#   [117  89  72]]
#
#  ...
#
#  [[163 133 108]
#   [165 135 110]
#   [166 136 111]
#   ...
#   [ 45  45  34]
#   [ 77  72  58]
#   [122 114  99]]
#
#  [[163 132 109]
#   [165 134 111]
#   [166 135 112]
#   ...
#   [ 31  36  27]
#   [ 41  43  31]
#   [ 96  95  81]]
#
#  [[163 132 109]
#   [165 134 111]
#   [166 135 112]
#   ...
#   [ 13  20  13]
#   [ 32  34  25]
#   [ 89  88  77]]]
# ----------------
# (200, 200, 3)
# [185 155 129]

# %%
print(image[257][45:400])
# Out:
# [144 145 145 147 147 147 147 147 147 147 147 147 147 148 149 150 150 151
#  151 150 150 150 150 150 150 150 150 153 153 153 154 154 155 155 155 153
#  153 154 155 155 156 157 157 157 158 159 159 160 160 159 159 159 159 159
#  160 160 160 161 161 160 160 160 160 160 160 160 160 161 161 161 161 161
#  161 161 161 160 161 163 164 164 162 160 158 166 164 162 159 158 158 159
#  160 162 160 156 153 148 142 135 130 123 119 115 112 111 110 108 107 105
#  104 104 105 106 105 102 100  94  91  88  85  84  84  83  81  79  83  88
#   90  87  87  97 110 110 107 104 102 102 102 100  98  90  92  93  90  87
#   85  87  90  85  87  84  86  89  67  35  19  31  24  28  79 118 121 125
#  118 131 127 125 125 121 118 120 125 133 125 108 108 124 116  73  33  17
#   21  36  52  53  43  45  57  62  65  69  73  76  78  79  79  85  90  92
#   92  97 107 112 111 113 114 114 115 116 119 125 129 132 135 137 137 135
#  132 132 132 128 135 141 146 154 164 169 168 164 163 154 147 154 165 171
# ...

# %%
print(image[200][40])
# Out:
# 142

# %%
for i in range(100):
   for j in range(img1.shape[2]):
       img1[i][j] = [random.randint(0, 255), random.randint(0, 255) , random.randint(0, 255)]
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
#for wait infinity no of times
cv2.waitKey(0)
cv2.destroyAllWindows()
